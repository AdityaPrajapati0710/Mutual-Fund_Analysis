# %%
import numpy as np
import pandas as pd 
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../DataSets/mutual_funds_india.csv")
df
# Out:
#       Unnamed: 0  AMC_name                                   Mutual Fund Name  \
# 0              0     Quant            Quant Small Cap Fund Direct Plan Growth
# 1              1    Canara         Canara Robeco Small Cap Fund Direct Growth
# 2              2      PGIM  PGIM India Midcap Opportunities Fund Direct Gr...
# 3              3      Bank         Bank of India Small Cap Fund Direct Growth
# 4              4     Quant                       Quant Tax Plan Direct Growth
# ...          ...       ...                                                ...
# 1083        1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth
# 1084        1084       BNP           BNP Paribas Overnight Fund Direct Growth
# 1085        1085   Invesco         Invesco India Overnight Fund Direct Growth
# 1086        1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth
# 1087        1087       ITI                   ITI Overnight Fund Direct Growth
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# AMC_name             object
# Mutual Fund Name     object
# category             object
# risk_type            object
# fund_rating         float64
# return_1yr          float64
# return_3yr          float64
# return_5yr          float64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0  fund_rating  return_1yr  return_3yr  return_5yr
# count  1088.000000   741.000000  975.000000  829.000000  696.000000
# mean    543.500000     3.066127    4.208585   13.563679    9.541135
# std     314.222851     1.102675    8.208132    9.016110    4.366601
# min       0.000000     1.000000  -39.000000   -9.240000   -2.950000
# 25%     271.750000     2.000000    2.155000    5.650000    6.300000
# 50%     543.500000     3.000000    3.750000   11.750000    8.650000
# 75%     815.250000     4.000000    5.640000   19.760000   12.790000
# max    1087.000000     5.000000   78.290000   54.370000   28.910000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# AMC_name              0
# Mutual Fund Name      0
# category              0
# risk_type             0
# fund_rating         347
# return_1yr          113
# return_3yr          259
# return_5yr          392
# dtype: int64

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.fund_rating = df.fund_rating.fillna(3.06)
df.return_1yr = df.return_1yr.fillna(0)
df.return_3yr = df.return_3yr.fillna(0)
df.return_5yr = df.return_5yr.fillna(0)

# %%
df
# Out:
#       AMC_name                                   Mutual Fund Name category  \
# 0        Quant            Quant Small Cap Fund Direct Plan Growth   Equity
# 1       Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 2         PGIM  PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# 3         Bank         Bank of India Small Cap Fund Direct Growth   Equity
# 4        Quant                       Quant Tax Plan Direct Growth   Equity
# ...        ...                                                ...      ...
# 1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth     Debt
# 1084       BNP           BNP Paribas Overnight Fund Direct Growth     Debt
# 1085   Invesco         Invesco India Overnight Fund Direct Growth     Debt
# 1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth     Debt
# 1087       ITI                   ITI Overnight Fund Direct Growth     Debt
#
# ...

# %%
eq = df[df.category == 'Equity']

# %%
eq
# Out:
#      AMC_name                                   Mutual Fund Name category  \
# 0       Quant            Quant Small Cap Fund Direct Plan Growth   Equity
# 1      Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 2        PGIM  PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# 3        Bank         Bank of India Small Cap Fund Direct Growth   Equity
# 4       Quant                       Quant Tax Plan Direct Growth   Equity
# ...       ...                                                ...      ...
# 1062     HSBC             HSBC Focused Equity Fund Direct Growth   Equity
# 1064     Tata                      Tata Quant Fund Direct Growth   Equity
# 1066     HSBC             HSBC Focused Equity Fund Direct Growth   Equity
# 1072      ITI                   ITI Large Cap Fund Direct Growth   Equity
# 1074      ITI                       ITI Value Fund Direct Growth   Equity
#
#            risk_type  fund_rating  return_1yr  return_3yr  return_5yr
# ...

# %%
db = df[df.category == 'Debt']

# %%
db
# Out:
#       AMC_name                                   Mutual Fund Name category  \
# 451       HDFC  HDFC Fixed Maturity Plan 1141 Days August 2018...     Debt
# 465        UTI                UTI Dynamic Bond Fund Direct Growth     Debt
# 471     Baroda  Baroda BNP Paribas Credit Risk Fund Direct Growth     Debt
# 480         JM            JM Low Duration Fund Direct Plan Growth     Debt
# 481        UTI                UTI Short term Income Direct Growth     Debt
# ...        ...                                                ...      ...
# 1083  Sundaram       Sundaram Ultra Short Term Fund Direct Growth     Debt
# 1084       BNP           BNP Paribas Overnight Fund Direct Growth     Debt
# 1085   Invesco         Invesco India Overnight Fund Direct Growth     Debt
# 1086      HSBC       HSBC Ultra Short Duration Fund Direct Growth     Debt
# 1087       ITI                   ITI Overnight Fund Direct Growth     Debt
#
# ...

# %%
hb = df[df.category == 'Hybrid']

# %%
hb
# Out:
#      AMC_name                                   Mutual Fund Name category  \
# 16      Quant                  Quant Absolute Fund Direct Growth   Hybrid
# 25      Quant               Quant Multi Asset Fund Direct Growth   Hybrid
# 50       Bank  Bank of India Mid & Small Cap Equity & Debt Fu...   Hybrid
# 134     ICICI  ICICI Prudential Equity & Debt Fund Direct Growth   Hybrid
# 151        JM                JM Equity Hybrid Fund Direct Growth   Hybrid
# ...       ...                                                ...      ...
# 1060     PGIM   PGIM India Balanced Advantage Fund Direct Growth   Hybrid
# 1077      ITI          ITI Balanced Advantage Fund Direct Growth   Hybrid
# 1079      ITI                   ITI Arbitrage Fund Direct Growth   Hybrid
# 1080      ITI                   ITI Arbitrage Fund Direct Growth   Hybrid
# 1082      ITI          ITI Balanced Advantage Fund Direct Growth   Hybrid
#
#                  risk_type  fund_rating  return_1yr  return_3yr  return_5yr
# ...

# %%
aa=df.set_index('AMC_name')

# %%
aa
# Out:
#                                            Mutual Fund Name category  \
# AMC_name
# Quant               Quant Small Cap Fund Direct Plan Growth   Equity
# Canara           Canara Robeco Small Cap Fund Direct Growth   Equity
# PGIM      PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# Bank             Bank of India Small Cap Fund Direct Growth   Equity
# Quant                          Quant Tax Plan Direct Growth   Equity
# ...                                                     ...      ...
# Sundaram       Sundaram Ultra Short Term Fund Direct Growth     Debt
# BNP                BNP Paribas Overnight Fund Direct Growth     Debt
# Invesco          Invesco India Overnight Fund Direct Growth     Debt
# HSBC           HSBC Ultra Short Duration Fund Direct Growth     Debt
# ITI                        ITI Overnight Fund Direct Growth     Debt
#
#                      risk_type  fund_rating  return_1yr  return_3yr  \
# AMC_name
# ...

# %%
bank = aa.loc[[ 'Canara', 'Bank', 'Kotak', 
       'Union',  'SBI',  'ICICI', 'IDBI',  'Axis',       
       'Baroda', 'IDFC', 'HDFC', 'HSBC' ]]

# %%
bank = bank.reset_index()
bank
# Out:
#     AMC_name                                   Mutual Fund Name category  \
# 0     Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 1     Canara         Canara Robeco Infrastructure Direct Growth   Equity
# 2     Canara   Canara Robeco Consumer Trends Fund Direct Growth   Equity
# 3     Canara       Canara Robeco Equity Tax Saver Direct Growth   Equity
# 4     Canara  Canara Robeco Emerging Equities Fund Direct Gr...   Equity
# ..       ...                                                ...      ...
# 429     HSBC                    HSBC Mid Cap Fund Direct Growth   Equity
# 430     HSBC  HSBC Global Equity Climate Change FoF Direct G...    Other
# 431     HSBC             HSBC Focused Equity Fund Direct Growth   Equity
# 432     HSBC             HSBC Focused Equity Fund Direct Growth   Equity
# 433     HSBC       HSBC Ultra Short Duration Fund Direct Growth     Debt
#
#                 risk_type  fund_rating  return_1yr  return_3yr  return_5yr
# ...

# %%
Non_Bank = aa.loc[['Quant',  'PGIM',  'Nippon', 'Edelweiss',
        'Tata', 'DSP',  'Invesco', 
       'Mirae', 'Sundaram', 'L&T', 'Motilal', 'UTI', 'Mahindra', 'Aditya',
        'Franklin', 'Parag', 'Templeton',
       'Taurus', 'Principal', 'IIFL', 'LIC', 'JM', 'Navi', 'Quantum',
       'BNP', 'Indiabulls', 'Shriram', 'ITI', 'Reliance', 'BOI',
       'WhiteOak', 'BHARAT', 'TRUSTMF', 'Samco', 'NJ']]

# %%
Non_Bank = Non_Bank.reset_index()
Non_Bank
# Out:
#     AMC_name                               Mutual Fund Name category  \
# 0      Quant        Quant Small Cap Fund Direct Plan Growth   Equity
# 1      Quant                   Quant Tax Plan Direct Growth   Equity
# 2      Quant        Quant Infrastructure Fund Direct Growth   Equity
# 3      Quant               Quant Mid Cap Fund Direct Growth   Equity
# 4      Quant             Quant Flexi Cap Fund Direct Growth   Equity
# ..       ...                                            ...      ...
# 649  TRUSTMF  TRUSTMF Banking & PSU Debt Fund Direct Growth     Debt
# 650  TRUSTMF          TRUSTMF Short Term Fund Direct Growth     Debt
# 651  TRUSTMF              TRUSTMF Liquid Fund Direct Growth     Debt
# 652    Samco             Samco Flexi Cap Fund Direct Growth   Equity
# 653       NJ       NJ Balanced Advantage Fund Direct Growth   Hybrid
#
#                 risk_type  fund_rating  return_1yr  return_3yr  return_5yr
# ...

# %%
q = bank.groupby(['AMC_name'])[['fund_rating','return_1yr','return_3yr','return_5yr']].mean()

# %%
q.plot(kind='bar')
plt.show()

# %%
p = Non_Bank.groupby(['AMC_name'])[['fund_rating','return_1yr','return_3yr','return_5yr']].mean()

# %%
p
# Out:
#             fund_rating  return_1yr  return_3yr  return_5yr
# AMC_name
# Aditya         2.865079    1.804127    9.836190    6.003968
# BHARAT         2.836000    2.498000    0.000000    0.000000
# BNP            3.020000    9.676667    8.903333    7.526667
# BOI            2.000000    3.200000    4.770000    5.970000
# DSP            2.948571   -0.120238   11.373810    5.978095
# Edelweiss      3.319355   -1.408710    9.556774    5.815806
# Franklin       2.545333    3.427667   13.141333    9.086667
# IIFL           3.265000    2.345000    8.770000    7.002500
# ITI            2.876471    1.135882    1.015882    0.000000
# Indiabulls     2.000000    3.220000    9.582222    3.747778
# Invesco        2.927647    1.024706    9.847059    6.032647
# JM             2.737333    3.407333    9.942667    6.817333
# L&T            2.488966    3.918621   11.105517    7.154483
# LIC            2.842105    3.708947   10.591053    7.493684
# ...

# %%
p.plot(kind='bar')
plt.show()

# %%
sb.barplot(x=bank.AMC_name , y=bank.return_1yr)
plt.xticks(rotation=90)
plt.show()

# %%
sb.barplot(x=Non_Bank.AMC_name , y=Non_Bank.return_1yr)
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize=[20,20])
x1 = fig.add_subplot(221)
sb.barplot(x=bank.AMC_name,y=bank.return_1yr)
plt.xticks(rotation=90)
plt.title('%s_Name_Wise_return_1yr', fontsize = 15)

x2=fig.add_subplot(222)
sb.barplot(x=bank.AMC_name,y=bank.return_3yr)
plt.xticks(rotation=90)
plt.title('%s_Name_Wise_return_3y',fontsize = 15)


x3=fig.add_subplot(223)
sb.barplot(x=bank.AMC_name,y=bank.fund_rating)
plt.xticks(rotation=90)
plt.title('%s_Name_Wise_Ratings',fontsize = 15)




plt.show()

# %%
bank['Diff'] = bank.return_3yr - bank.return_1yr

# %%
Non_Bank['Diff'] = Non_Bank.return_3yr - Non_Bank.return_1yr

# %%
t1 = bank.nlargest(5,'return_1yr')
t1
# Out:
#     AMC_name                                  Mutual Fund Name category  \
# 291   Baroda                  Baroda Midcap Direct Fund Growth   Equity
# 98       SBI  SBI Consumption Opportunities Fund Direct Growth   Equity
# 170    ICICI      ICICI Prudential BHARAT 22 FOF Direct Growth    Other
# 366     HDFC           HDFC Focused 30 Fund Direct Plan Growth   Equity
# 150    ICICI     ICICI Prudential Infrastructure Direct Growth   Equity
#
#           risk_type  fund_rating  return_1yr  return_3yr  return_5yr   Diff
# 291  Very High Risk          4.0       27.49       23.56       16.94  -3.93
# 98   Very High Risk          3.0       27.14       25.65       16.34  -1.49
# 170  Very High Risk          1.0       27.14       16.53        0.00 -10.61
# 366  Very High Risk          2.0       23.54       22.50       11.72  -1.04
# 150  Very High Risk          4.0       22.31       25.50       13.88   3.19

# %%
t3 = bank.nlargest(5,'return_3yr')
t3
# Out:
#    AMC_name                            Mutual Fund Name category  \
# 0    Canara  Canara Robeco Small Cap Fund Direct Growth   Equity
# 21     Bank  Bank of India Small Cap Fund Direct Growth   Equity
# 35    Kotak          Kotak Small Cap Fund Direct Growth   Equity
# 77    Union          Union Small Cap Fund Direct Growth   Equity
# 94      SBI            SBI Small Cap Fund Direct Growth   Equity
#
#          risk_type  fund_rating  return_1yr  return_3yr  return_5yr   Diff
# 0   Very High Risk          5.0       20.09       44.48        0.00  24.39
# 21  Very High Risk          5.0       13.16       44.13        0.00  30.97
# 35  Very High Risk          4.0       10.06       39.13       19.66  29.07
# 77  Very High Risk          3.0       11.19       35.94       16.13  24.75
# 94  Very High Risk          4.0       19.32       34.37       20.49  15.05

# %%
t5 = bank.nlargest(5,'return_5yr')
t5
# Out:
#     AMC_name                                 Mutual Fund Name category  \
# 145    ICICI   ICICI Prudential Technology Direct Plan Growth   Equity
# 99       SBI  SBI Technology Opportunities Fund Direct Growth   Equity
# 243     Axis                Axis Small Cap Fund Direct Growth   Equity
# 94       SBI                 SBI Small Cap Fund Direct Growth   Equity
# 35     Kotak               Kotak Small Cap Fund Direct Growth   Equity
#
#           risk_type  fund_rating  return_1yr  return_3yr  return_5yr   Diff
# 145  Very High Risk         3.06      -14.60       29.99       28.00  44.59
# 99   Very High Risk         3.06      -11.86       25.58       25.85  37.44
# 243  Very High Risk         5.00       11.35       32.00       21.46  20.65
# 94   Very High Risk         4.00       19.32       34.37       20.49  15.05
# 35   Very High Risk         4.00       10.06       39.13       19.66  29.07

# %%
sb.pairplot(bank)
plt.show()
# Out:
# C:\Users\ap728\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.countplot(x=bank.AMC_name,hue = bank.fund_rating)
plt.xticks(rotation=90)
plt.show()

# %%
sb.boxplot(data = bank,x=bank.AMC_name,y=bank.return_1yr)
plt.xticks(rotation=90)
plt.show()

# %%
aa=df.risk_type.value_counts()

# %%
bb= df[df.risk_type == all].all()
bb=aa

# %%
aa
# Out:
# risk_type
# Very High Risk          571
# Moderate Risk           157
# Low to Moderate Risk    155
# Moderately High Risk     94
# Low Risk                 61
# High Risk                42
# Moderately Low Risk       8
# Name: count, dtype: int64

# %%
def Check():
    while True:
        ch = input("Enter your choice (Bank or nonbank):")
        
        if ch in ["Bank", "nonbank"]:
            break
        else:
            print("Invalid choice...Please enter 'Bank' or 'nonbank'.")
    
    if ch == "Bank":
        print(bank.category.unique())
        vrr3 = input("Enter Category:")
        vrr4 = df[df.category == vrr3]
        
        print(bank.AMC_name.unique())
        vrr5 = input("Enter AMC_Name:")
        vrr6 = vrr4[vrr4.AMC_name == vrr5]
        
        
        fig = plt.figure(figsize=[30, 20])
        x1 = fig.add_subplot(221)
        sb.barplot(x=vrr6['Mutual Fund Name'], y=vrr6.return_3yr, palette='ocean')
        plt.xticks(rotation=90)
        plt.show()
        
        x2=fig.add_subplot(222)
        sb.barplot(x=vrr6['Mutual Fund Name'],y=vrr6.fund_rating,palette='ocean')
        plt.xticks(rotation=90)
        plt.show()
        
        x2=fig.add_subplot(223)
        sb.countplot(data=bank,x=vrr6['Mutual Fund Name'],hue='risk_type')
        plt.xticks(rotation=90)
        plt.show()
        
        x2=fig.add_subplot(223)
        sb.barplot(x=vrr6['Mutual Fund Name'],y=bank.Diff)
        plt.xticks(rotation=90)
        plt.show()

        
        
        
        
        
        
    
    elif ch == "nonbank":
        print(Non_Bank.category.unique())
        vrr7 = input("Enter Category:")
        vrr8 = df[df.category == vrr7]
        
        print(Non_Bank.AMC_name.unique())
        vrr9 = input("Enter AMC_Name:")
        vrr10 = vrr8[vrr8.AMC_name == vrr9]
        
        fig = plt.figure(figsize=[30, 20])
        x1 = fig.add_subplot(221)
        sb.barplot(x=vrr10['Mutual Fund Name'], y=vrr10.return_3yr, palette='ocean')
        plt.xticks(rotation=90)
        plt.show()
        
        x2=fig.add_subplot(222)
        sb.barplot(x=vrr10['Mutual Fund Name'],y=vrr10.fund_rating,palette='ocean')
        plt.xticks(rotation=90)
        plt.show()
        
        x2=fig.add_subplot(223)
        sb.countplot(data=Non_Bank,x=vrr10['Mutual Fund Name'],hue='risk_type')
        plt.xticks(rotation=90)
        plt.show()
        
        x2=fig.add_subplot(223)
        sb.barplot(x=vrr10['Mutual Fund Name'],y=Non_Bank.Diff)
        plt.xticks(rotation=90)
        plt.show()

        
       
    
    else:
        print("You have entered the wrong choice.....")

        
            
        
    
Check()
# Out:
# Enter your choice (Bank or nonbank):Bank
# ['Equity' 'Hybrid' 'Debt' 'Other' 'Solution Oriented']
# Enter Category:Equity
# ['Canara' 'Bank' 'Kotak' 'Union' 'SBI' 'ICICI' 'IDBI' 'Axis' 'Baroda'
#  'IDFC' 'HDFC' 'HSBC']
# Enter AMC_Name:ICICI

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 vrr6
#
# NameError: name 'vrr6' is not defined
